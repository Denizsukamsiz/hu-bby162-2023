# %% [markdown]
# <a href="https://colab.research.google.com/github/Denizsukamsiz/hu-bby162-2023/blob/main/final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
dosya = "/content/drive/MyDrive/Colab Notebooks/veri.txt"

def deneme():
  islem = open(dosya,"r")
  for index, veri in enumerate(islem):
    print(islem)

#Katalog uygulamasında açılışında menü...
def ana_menu():
    print("******** Hoş geldiniz **********")
    print("1- Eserleri Listele...")
    print("2- Kataloga Yeni Eser Ekle...")
    print("3- Katalogdan Eser Sil...")
    print("4- Katalogdaki eserleri temizle...")
    print("5- Eseri güncelle...")
    print("6- Katalogda arama yap...")
    print("0- Çıkış...")

    tuslama = input("Lütfen seçenek giriniz : ")

    if tuslama == "1": #eser listelemek
        print("eserler listeleniyor lütfen bekleyiniz...")
        katalog = [
            {"Eser Adı": "Aşk ve Gurur", "Yazar": "Jane Austen", "Basım Yılı": 1813},
            {"Eser Adı": "Hayvan Çiftliği", "Yazar": "George Orwell", "Basım Yılı": 1945},
            {"Eser Adı": "Yeşil Peri Gecesi", "Yazar": "F. Scott Fitzgerald", "Basım Yılı": 1925},
            {"Eser Adı": "İçimizdeki Şeytan", "Yazar": "Sabahattin Ali", "Basım Yılı": 1940},
            {"Eser Adı": "Son Ada", "Yazar": "Zülfü Livaneli", "Basım Yılı": 2000}
        ]

        for eser in katalog:
            print(eser)

    elif tuslama == "2": #eser eklemek
        katalog = [
            {"Eser Adı": "Aşk ve Gurur", "Yazar": "Jane Austen", "Basım Yılı": 1813},
            {"Eser Adı": "Hayvan Çiftliği", "Yazar": "George Orwell", "Basım Yılı": 1945},
            {"Eser Adı": "Yeşil Peri Gecesi", "Yazar": "F. Scott Fitzgerald", "Basım Yılı": 1925},
            {"Eser Adı": "İçimizdeki Şeytan", "Yazar": "Sabahattin Ali", "Basım Yılı": 1940},
            {"Eser Adı": "Son Ada", "Yazar": "Zülfü Livaneli", "Basım Yılı": 2000}
        ]

        while True:
            eser_ismi = input("Eser İsmi (çıkış yapmak için '0' tuşuna basınız): ")
            if eser_ismi == '0':
                break

            yazar = input("Yazar: ")
            basim_yili = input("Basım Yılı: ")
            katalog.append({"Eser Adı": eser_ismi, "Yazar": yazar, "Basım Yılı": basim_yili})

        print("Güncellenen Katalog:")
        for eser in katalog:
            print(f"Eser Adı: {eser['Eser Adı']}, Yazar: {eser['Yazar']}, Basım Yılı: {eser['Basım Yılı']}")

    elif tuslama == "3": #eser silmek

        katalog = [
            {"Eser Adı": "Aşk ve Gurur", "Yazar": "Jane Austen", "Basım Yılı": 1813},
            {"Eser Adı": "Hayvan Çiftliği", "Yazar": "George Orwell", "Basım Yılı": 1945},
            {"Eser Adı": "Yeşil Peri Gecesi", "Yazar": "F. Scott Fitzgerald", "Basım Yılı": 1925},
            {"Eser Adı": "İçimizdeki Şeytan", "Yazar": "Sabahattin Ali", "Basım Yılı": 1940},
            {"Eser Adı": "Son Ada", "Yazar": "Zülfü Livaneli", "Basım Yılı": 2000}
        ]

        eser_ismi = input("Silmek istediğiniz eserin adını girin: ")

        for eser in katalog:
            if eser["Eser Adı"] == eser_ismi:
                katalog.remove(eser)

        print("Güncellenen Katalog:")
        for eser in katalog:
            print(f"Eser Adı: {eser['Eser Adı']}, Yazar: {eser['Yazar']}, Basım Yılı: {eser['Basım Yılı']}")

    elif tuslama == "4": #bütün eserleri temizlemek
        katalog = [
            {"Eser Adı": "Aşk ve Gurur", "Yazar": "Jane Austen", "Basım Yılı": 1813},
            {"Eser Adı": "Hayvan Çiftliği", "Yazar": "George Orwell", "Basım Yılı": 1945},
            {"Eser Adı": "Yeşil Peri Gecesi", "Yazar": "F. Scott Fitzgerald", "Basım Yılı": 1925},
            {"Eser Adı": "İçimizdeki Şeytan", "Yazar": "Sabahattin Ali", "Basım Yılı": 1940},
            {"Eser Adı": "Son Ada", "Yazar": "Zülfü Livaneli", "Basım Yılı": 2000}
        ]

        katalog.clear()

        print("Katalog temizleniyor...")
        print("Güncel katalog:", katalog)

    elif tuslama == "0":  #tuşa basarak program sonlandırma...
        print("Programdan çıkış yapılıyor.....")

    elif tuslama == "5": #Eseri güncellemek
        katalog = [
            {"Eser Adı": "Aşk ve Gurur", "Yazar": "Jane Austen", "Basım Yılı": 1813},
            {"Eser Adı": "Hayvan Çiftliği", "Yazar": "George Orwell", "Basım Yılı": 1945},
            {"Eser Adı": "Yeşil Peri Gecesi", "Yazar": "F. Scott Fitzgerald", "Basım Yılı": 1925},
            {"Eser Adı": "İçimizdeki Şeytan", "Yazar": "Sabahattin Ali", "Basım Yılı": 1940},
            {"Eser Adı": "Son Ada", "Yazar": "Zülfü Livaneli", "Basım Yılı": 2000}
        ]

        eser_ismi_sil = input("Silmek istediğiniz eserin adını girin: ")

        for eser in katalog:
            if eser["Eser Adı"] == eser_ismi_sil:
                katalog.remove(eser)
                break

        eser_ismi_guncel = input("Güncellemek istediğiniz eserin adını girin: ")
        yazar_guncel = input("Yazar: ")
        basim_yili_guncel = input("Basım Yılı: ")

        katalog.append({"Eser Adı": eser_ismi_guncel, "Yazar": yazar_guncel, "Basım Yılı": basim_yili_guncel})

        print("Güncellenen Katalog:")
        for eser in katalog:
            print(f"Eser Adı: {eser['Eser Adı']}, Yazar: {eser['Yazar']}, Basım Yılı: {eser['Basım Yılı']}")


    if tuslama == "6":  #basit arama yapmak
        katalog = [
            {"Eser Adı": "Aşk ve Gurur", "Yazar": "Jane Austen", "Basım Yılı": 1813},
            {"Eser Adı": "Hayvan Çiftliği", "Yazar": "George Orwell", "Basım Yılı": 1945},
            {"Eser Adı": "Yeşil Peri Gecesi", "Yazar": "F. Scott Fitzgerald", "Basım Yılı": 1925},
            {"Eser Adı": "İçimizdeki Şeytan", "Yazar": "Sabahattin Ali", "Basım Yılı": 1940},
            {"Eser Adı": "Son Ada", "Yazar": "Zülfü Livaneli", "Basım Yılı": 2000}
        ]

        arama_terimi = input("Aramak istediğiniz terimi (eser, yazar, basım yılı) girin: ")

        for eser in katalog:
            if arama_terimi.lower() == eser["Eser Adı"].lower():
                print(f"Yayın Yılı: {eser['Basım Yılı']}, Yazar: {eser['Yazar']}")
            elif arama_terimi.lower() == eser["Yazar"].lower():
                print(f"Eser Adı: {eser['Eser Adı']}, Basım Yılı: {eser['Basım Yılı']}")
            elif arama_terimi == eser["Basım Yılı"]:
                print(f"Eser Adı: {eser['Eser Adı']}, Yazar: {eser['Yazar']}")




if __name__ == "__main__":
    ana_menu()
# Out:
# ******** Hoş geldiniz **********
# 1- Eserleri Listele...
# 2- Kataloga Yeni Eser Ekle...
# 3- Katalogdan Eser Sil...
# 4- Katalogdaki eserleri temizle...
# 5- Eseri güncelle...
# 6- Katalogda arama yap...
# 0- Çıkış...
# Lütfen seçenek giriniz : 1
# eserler listeleniyor lütfen bekleyiniz...
# {'Eser Adı': 'Aşk ve Gurur', 'Yazar': 'Jane Austen', 'Basım Yılı': 1813}
# {'Eser Adı': 'Hayvan Çiftliği', 'Yazar': 'George Orwell', 'Basım Yılı': 1945}
# {'Eser Adı': 'Yeşil Peri Gecesi', 'Yazar': 'F. Scott Fitzgerald', 'Basım Yılı': 1925}
# {'Eser Adı': 'İçimizdeki Şeytan', 'Yazar': 'Sabahattin Ali', 'Basım Yılı': 1940}
# {'Eser Adı': 'Son Ada', 'Yazar': 'Zülfü Livaneli', 'Basım Yılı': 2000}
